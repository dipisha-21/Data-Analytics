# %% [markdown]
# ## The data of different cars is given with their specifications.
#
#
# ## This data is available as a CSV file. We are going to analyze this data set using the Pandas DataFrame.

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\KIIT\Downloads\archive (1)\Automobile.csv")

# %%
data
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
data.head(20)
# Out:
#                             name   mpg  cylinders  displacement  horsepower  \
# 0      chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1              buick skylark 320  15.0          8         350.0       165.0
# 2             plymouth satellite  18.0          8         318.0       150.0
# 3                  amc rebel sst  16.0          8         304.0       150.0
# 4                    ford torino  17.0          8         302.0       140.0
# 5               ford galaxie 500  15.0          8         429.0       198.0
# 6               chevrolet impala  14.0          8         454.0       220.0
# 7              plymouth fury iii  14.0          8         440.0       215.0
# 8               pontiac catalina  14.0          8         455.0       225.0
# 9             amc ambassador dpl  15.0          8         390.0       190.0
# 10           dodge challenger se  15.0          8         383.0       170.0
# ...

# %%
data.shape
# Out:
# (398, 9)

# %%
data.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %% [markdown]
# # Show all car company

# %%
data['name'].value_counts()
# Out:
# ford pinto             6
# toyota corolla         5
# amc matador            5
# ford maverick          5
# chevrolet chevette     4
#                       ..
# chevrolet monza 2+2    1
# ford mustang ii        1
# pontiac astro          1
# amc pacer              1
# chevy s-10             1
# Name: name, Length: 305, dtype: int64

# %% [markdown]
# # Maximum Horsepower

# %%
data['horsepower'].max()
# Out:
# 230.0

# %% [markdown]
# # Minimum Displacement

# %%
data['displacement'].min()
# Out:
# 68.0

# %% [markdown]
# # Mean Weight

# %%
data['weight'].mean()
# Out:
# 2970.424623115578

# %% [markdown]
# # Fastest acceleration

# %%
data['acceleration'].min()
# Out:
# 8.0

# %%
data[data['acceleration'].isin([8])]
# Out:
#                   name   mpg  cylinders  displacement  horsepower  weight  \
# 11  plymouth 'cuda 340  14.0          8         340.0       160.0    3609
#
#     acceleration  model_year origin
# 11           8.0          70    usa

# %% [markdown]
# # Number of cars in the different years

# %%
data['model_year'].value_counts()
# Out:
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 70    29
# 79    29
# 80    29
# 81    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: model_year, dtype: int64

# %% [markdown]
# # Number of cars from different origins

# %%
data['origin'].value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %% [markdown]
# # Show cars having only japan and europes as it's origin

# %%
data[data['origin'].isin(['japan', 'europe'])]
# Out:
#                              name   mpg  cylinders  displacement  horsepower  \
# 14          toyota corona mark ii  24.0          4         113.0        95.0
# 18                   datsun pl510  27.0          4          97.0        88.0
# 19   volkswagen 1131 deluxe sedan  26.0          4          97.0        46.0
# 20                    peugeot 504  25.0          4         110.0        87.0
# 21                    audi 100 ls  24.0          4         107.0        90.0
# ..                            ...   ...        ...           ...         ...
# 383                   honda civic  38.0          4          91.0        67.0
# 384            honda civic (auto)  32.0          4          91.0        67.0
# 385                 datsun 310 gx  38.0          4          91.0        67.0
# 390              toyota celica gt  32.0          4         144.0        96.0
# 394                     vw pickup  44.0          4          97.0        52.0
#
# ...

# %% [markdown]
# # Remove all data having weight more than 4000

# %%
data[~(data['weight'] > 4000)]
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %% [markdown]
# # Increase all mpg values by 3

# %%
data['mpg'] =  data['mpg'].apply(lambda x:x+3)

# %%
data
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  21.0          8         307.0       130.0
# 1            buick skylark 320  18.0          8         350.0       165.0
# 2           plymouth satellite  21.0          8         318.0       150.0
# 3                amc rebel sst  19.0          8         304.0       150.0
# 4                  ford torino  20.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  30.0          4         140.0        86.0
# 394                  vw pickup  47.0          4          97.0        52.0
# 395              dodge rampage  35.0          4         135.0        84.0
# 396                ford ranger  31.0          4         120.0        79.0
# 397                 chevy s-10  34.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %% [markdown]
# # Minimum and Maximum values groupby Origin

# %% [markdown]
# ### Minimum

# %%
data.groupby('origin').min()
# Out:
#                            name   mpg  cylinders  displacement  horsepower  \
# origin
# europe              audi 100 ls  19.2          4          68.0        46.0
# japan               datsun 1200  21.0          3          70.0        52.0
# usa     amc ambassador brougham  12.0          4          85.0        52.0
#
#         weight  acceleration  model_year
# origin
# europe    1825          12.2          70
# japan     1613          11.4          70
# usa       1800           8.0          70

# %% [markdown]
# ### Maximum

# %%
data.groupby('origin').max()
# Out:
#                                name   mpg  cylinders  displacement  \
# origin
# europe             vw rabbit custom  47.3          6         183.0
# japan   toyouta corona mark ii (sw)  49.6          6         168.0
# usa              pontiac ventura sj  42.0          8         455.0
#
#         horsepower  weight  acceleration  model_year
# origin
# europe       133.0    3820          24.8          82
# japan        132.0    2930          21.0          82
# usa          230.0    5140          22.2          82

# %% [markdown]
# # Cars with horsepower more than 3500 or acceleration less than 10 and weight more than 2500

# %%
data[(data['horsepower'] > 3500) & (data['acceleration'] < 10)|(data['weight'] > 2500)]
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  21.0          8         307.0       130.0
# 1            buick skylark 320  18.0          8         350.0       165.0
# 2           plymouth satellite  21.0          8         318.0       150.0
# 3                amc rebel sst  19.0          8         304.0       150.0
# 4                  ford torino  20.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 390           toyota celica gt  35.0          4         144.0        96.0
# 392           chevrolet camaro  30.0          4         151.0        90.0
# 393            ford mustang gl  30.0          4         140.0        86.0
# 396                ford ranger  31.0          4         120.0        79.0
# 397                 chevy s-10  34.0          4         119.0        82.0
#
#      weight  acceleration  model_year origin
# ...
